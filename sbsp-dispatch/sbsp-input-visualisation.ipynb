# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

day_ahead_prices_df = pd.read_csv('../data/day_ahead_prices_all_domains_20150101-20241231.csv', index_col=0, parse_dates=True)

day_ahead_prices_df.replace(-10000, np.nan, inplace=True)
day_ahead_prices_df.head()
# Out:
#                                 AT       BE       BG     CH     CZ  DE_AT_LU  \
# datetime
# 2015-01-01 00:00:00+00:00 -10000.0 -10000.0 -10000.0  43.43  24.20  -10000.0
# 2015-01-01 01:00:00+00:00 -10000.0 -10000.0 -10000.0  38.08  22.06  -10000.0
# 2015-01-01 02:00:00+00:00 -10000.0 -10000.0 -10000.0  35.47  20.27  -10000.0
# 2015-01-01 03:00:00+00:00 -10000.0 -10000.0 -10000.0  30.83  19.17  -10000.0
# 2015-01-01 04:00:00+00:00 -10000.0 -10000.0 -10000.0  28.26  17.90  -10000.0
#
#                              DE_LU   DK_1   DK_2     EE  ...      RO       RS  \
# datetime                                                 ...
# 2015-01-01 00:00:00+00:00 -10000.0  18.29  18.29  23.37  ...  198.00 -10000.0
# 2015-01-01 01:00:00+00:00 -10000.0  16.04  16.04  19.33  ...  175.59 -10000.0
# 2015-01-01 02:00:00+00:00 -10000.0  14.60  14.60  17.66  ...  120.72 -10000.0
# 2015-01-01 03:00:00+00:00 -10000.0  14.95  14.95  17.53  ...   93.87 -10000.0
# ...

# %%
plt.figure(figsize=(20,8))
day_ahead_prices_df.boxplot()
plt.xticks(rotation=90)
plt.title('Boxplot of Day-Ahead Prices by Market')
plt.ylabel('Price (€/MWh)')
plt.grid(True)
plt.show()
